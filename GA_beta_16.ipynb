# %% [markdown]
# <a href="https://colab.research.google.com/github/seyonechithrananda/ncov-ligand-protein/blob/master/GA_beta_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/My\ Drive/Project\ De\ Novo/GA
# Out:
# /content/drive/My Drive/Project De Novo/GA

# %%
# !pwd
# Out:
# /content/drive/My Drive/Project De Novo/GA

# %%
#!git clone https://github.com/aspuru-guzik-group/GA.git
# Out:
# Cloning into 'GA'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 93294 (delta 29), reused 30 (delta 13), pack-reused 93245
# Receiving objects: 100% (93294/93294), 2.01 GiB | 17.62 MiB/s, done.
# Resolving deltas: 100% (17267/17267), done.

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-05-15 22:10:22--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  81.12M  79.4MB/s    in 1.0s
#
# 2020-05-15 22:10:23 (79.4 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !pip install selfies

# %%
# !conda install numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          46 KB
#     certifi-2020.4.5.1         |           py37_0         155 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     numpy-1.18.1               |   py37h94c655d_0           5 KB
#     numpy-base-1.18.1          |   py37h2f8d375_1         4.2 MB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     ------------------------------------------------------------
#                                            Total:         9.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-openblas
#   numpy-base         pkgs/main/linux-64::numpy-base-1.18.1-py37h2f8d375_1
# ...

# %%
# !conda install pytorch torchvision cudatoolkit=10.2 -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-10.2.89        |       hfd86e86_1       365.1 MB
#     intel-openmp-2020.1        |              217         780 KB
#     mkl-2020.1                 |              217       129.0 MB
#     ninja-1.9.0                |   py37hfd86e86_0         1.2 MB
#     pytorch-1.0.0              |py3.7_cuda9.0.176_cudnn7.4.1_1       498.7 MB  pytorch
#     torchvision-0.2.2          |             py_3          44 KB  pytorch
#     ------------------------------------------------------------
#                                            Total:       994.7 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !conda install -c conda-forge tensorboardx
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tensorboardx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libprotobuf-3.11.4         |       h8b12597_0         4.8 MB  conda-forge
#     protobuf-3.11.4            |   py37h3340039_1         695 KB  conda-forge
#     tensorboardx-2.0           |             py_0          77 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.11.4-h8b12597_0
#   protobuf           conda-forge/linux-64::protobuf-3.11.4-py37h3340039_1
#   tensorboardx       conda-forge/noarch::tensorboardx-2.0-py_0
#
# The following packages will be UPDATED:
#
# ...

# %%
from selfies import encoder

filename = '/content/drive/My Drive/Project De Novo/GA/GA/datasets/zinc_dearom.txt'

with open(filename) as f:
    content = f.readlines()
smiles_list = [x.strip() for x in content] 

selfies_list = []

for smi in smiles_list:
  selfies_list.append(encoder(smi))

print (selfies_list)
# Out:
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# ...

# %%
# %cd GA
# !pwd
# Out:
# /content/drive/My Drive/Project De Novo/GA/GA
# /content/drive/My Drive/Project De Novo/GA/GA

# %%
# !nvidia-smi
# Out:
# Fri May 15 05:08:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
'''
Edited starting_selfies to include hits (some weren't processed due to errors with the library). Also edited the discriminator's training set to only
include hits for 3clpro in SARS-COV-1/2
'''

# We modify core_GA.py to pass a smiles_list and selfies_list to initialize the GA.
# Additionally, we explore several different values for beta, or the weightage of the discriminators predictions



# !python ./core_GA.py
# Out:
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# ...

# %% [markdown]
# Experiment Params:
# - beta_value for discriminator = 16
# - num_generations = 200
# - generation_size = 500
# - moved to cpu from GPU (would recommend doing for above as well)
# - starting_selfies = 540~ hits from 3clpro inhibition (sars-cov-1/2) + high antiviral activity molecules. Should be interesting to start the chemical design off of.
#
# core_GA.py was modified to accept all the hits, and I skipped over SMILES which didn't process properly in the library in evo_functions.py
#
# Note: I should probably re-train the beta=0 version with CPU, might make a difference. Also, I should consider moving to AWS or local since it uses CPU anyways, because Colab disconnects really often now.

# %%
# !python core_GA.py
# Out:
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: /
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# _smiles_to_selfies: Unknown Symbol: \
# Could not encode smiles string. Please contact authors.
# ...
