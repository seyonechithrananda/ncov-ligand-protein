# %% [markdown]
# <a href="https://colab.research.google.com/github/seyonechithrananda/ncov-ligand-protein/blob/master/Chemprop_3clpro_activity_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda init --all
# Out:
# --2020-05-14 05:14:07--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# Extracting : libgfortran-ng-7.3.0-hdf63c60_5.tar.bz2:  67% 124/185 [01:01<00:22,  2.70it/s]Traceback (most recent call last):
#   File "entry_point.py", line 69, in <module>
#   File "concurrent/futures/process.py", line 483, in _chain_from_iterable_of_lists
#   File "concurrent/futures/_base.py", line 598, in result_iterator
#   File "concurrent/futures/_base.py", line 430, in result
#   File "threading.py", line 296, in wait
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
# ...

# %%
# !conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# !git clone https://github.com/chemprop/chemprop.git
# Out:
# fatal: destination path 'chemprop' already exists and is not an empty directory.

# %%
# %cd /content/chemprop
# Out:
# /content/chemprop

# %%
# !conda install -q -y -c conda-forge flask>=1.1.2

# %%
# !conda install -q -y -c conda-forge gunicorn>=20.0.4

# %%
# !conda install hyperopt>=0.2.3

# %%
# !conda install numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          46 KB
#     certifi-2020.4.5.1         |           py37_0         155 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     numpy-1.18.1               |   py37h94c655d_0           5 KB
#     numpy-base-1.18.1          |   py37h2f8d375_1         4.2 MB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     ------------------------------------------------------------
#                                            Total:         9.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-openblas
#   numpy-base         pkgs/main/linux-64::numpy-base-1.18.1-py37h2f8d375_1
# ...

# %%
# !conda install scikit-learn
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-0.14.1              |             py_0         201 KB
#     scikit-learn-0.22.1        |   py37h22eb022_0         5.3 MB
#     ------------------------------------------------------------
#                                            Total:         5.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             pkgs/main/noarch::joblib-0.14.1-py_0
#   scikit-learn       pkgs/main/linux-64::scikit-learn-0.22.1-py37h22eb022_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# scikit-learn-0.22.1  | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.47it/s]
# joblib-0.14.1        | 201 KB    | : 100% 1.0/1 [00:00<00:00, 17.45it/s]
# done
# done
# done

# %%
# !conda install scipy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scipy-1.4.1                |   py37habc2bb6_0        14.6 MB
#     ------------------------------------------------------------
#                                            Total:        14.6 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   scipy              conda-forge::scipy-1.4.1-py37ha3d9a3c~ --> pkgs/main::scipy-1.4.1-py37habc2bb6_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# scipy-1.4.1          | 14.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.05s/it]
# done
# done
# done

# %%
# !conda install pytorch torchvision cudatoolkit=10.2 -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     intel-openmp-2020.1        |              217         780 KB
#     mkl-2020.1                 |              217       129.0 MB
#     ninja-1.9.0                |   py37hfd86e86_0         1.2 MB
#     pytorch-1.0.0              |py3.7_cuda9.0.176_cudnn7.4.1_1       498.7 MB  pytorch
#     torchvision-0.2.2          |             py_3          44 KB  pytorch
#     ------------------------------------------------------------
#                                            Total:       629.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-10.2.89-hfd86e86_1
# ...

# %%
# !pip install typed-argument-parser>=1.4.3
# !pip install git+https://github.com/bp-kelley/descriptastorus
# Out:
# ...
#   Cloning https://github.com/bp-kelley/descriptastorus to /tmp/pip-req-build-ggbystyw
#   Running command git clone -q https://github.com/bp-kelley/descriptastorus /tmp/pip-req-build-ggbystyw
# ...
#   Created wheel for descriptastorus: filename=descriptastorus-2.2.0.2-py3-none-any.whl size=59506 sha256=1d8f786f565b509a4856d08e025b01cf05c335dc809f284cb4996ef7c8edaf35
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1ihrwhd4/wheels/f9/c3/4f/e7d01f4f2f1a89aef8f0ef088beb4a94976324f3ee21410b10
# Successfully built descriptastorus
# ...

# %%
# !conda install tqdm
# !conda install matplotlib
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.46.0                |             py_0          60 KB
#     ------------------------------------------------------------
#                                            Total:          60 KB
#
# The following packages will be UPDATED:
#
#   tqdm                                          4.42.1-py_0 --> 4.46.0-py_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# tqdm-4.46.0          | 60 KB     | : 100% 1.0/1 [00:00<00:00, 10.99it/s]
# done
# done
# done
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# ...

# %%
# !conda install -c conda-forge tensorboardx
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tensorboardx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     protobuf-3.11.4            |   py37h3340039_1         695 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         695 KB
#
# The following NEW packages will be INSTALLED:
#
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.11.4-h8b12597_0
#   protobuf           conda-forge/linux-64::protobuf-3.11.4-py37h3340039_1
#   tensorboardx       conda-forge/noarch::tensorboardx-2.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.4.5.1-hecc5488_0
# ...

# %%
# !pwd
# Out:
# /content/chemprop

# %%
# !python predict.py --test_path /content/drive/My\ Drive/Project\ De\ Novo/chemprop/broad_positive_molecules.csv --checkpoint_dir /content/drive/My\ Drive/Project\ De\ Novo/chemprop/SARS-balanced --preds_path /content/drive/My\ Drive/Project\ De\ Novo/chemprop/chemprop_preds.csv --features_generator rdkit_2d_normalized --no_features_scaling
# Out:
# Loading training args
# Loading data
# 1246it [00:00, 270124.71it/s]
# 100% 1246/1246 [00:58<00:00, 21.27it/s]
# Validating SMILES
# Test size = 1,246
# Predicting with an ensemble of 5 models
#   0% 0/5 [00:00<?, ?it/s]Loading pretrained parameter "encoder.encoder.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.W_i.weight".
# Loading pretrained parameter "encoder.encoder.W_h.weight".
# Loading pretrained parameter "encoder.encoder.W_o.weight".
# Loading pretrained parameter "encoder.encoder.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Moving model to cuda
#
#   0% 0/25 [00:00<?, ?it/s]
#   4% 1/25 [00:00<00:17,  1.35it/s]
#  12% 3/25 [00:00<00:12,  1.82it/s]
#  24% 6/25 [00:01<00:07,  2.53it/s]
#  36% 9/25 [00:01<00:04,  3.46it/s]
# 100% 25/25 [00:01<00:00, 13.88it/s]
# ...
