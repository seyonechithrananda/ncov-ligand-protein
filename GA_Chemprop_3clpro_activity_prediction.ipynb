# %% [markdown]
# <a href="https://colab.research.google.com/github/seyonechithrananda/ncov-ligand-protein/blob/master/GA_Chemprop_3clpro_activity_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test: Load highest scoring molecules from genetic algorithm for scoring by ChemProp

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda init --all
# Out:
# --2020-05-16 04:48:25--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  81.12M   192MB/s    in 0.4s
#
# 2020-05-16 04:48:25 (192 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-1.72.0               |   py37h9de70de_0         316 KB  conda-forge
#     boost-cpp-1.72.0           |       h8e57a91_0        21.8 MB  conda-forge
#     bzip2-1.0.8                |       h516909a_2         396 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     cairo-1.16.0               |    hcf35c78_1003         1.5 MB  conda-forge
#     certifi-2020.4.5.1         |   py37hc8dfbb8_0         151 KB  conda-forge
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     fontconfig-2.13.1          |    h86ecdb6_1001         340 KB  conda-forge
# ...

# %%
# %cd /content/drive/My Drive/Project De Novo/chemprop
# !pwd
# Out:
# /content/drive/My Drive/Project De Novo/chemprop
# /content/drive/My Drive/Project De Novo/chemprop

# %%
# !git clone https://github.com/chemprop/chemprop.git
# Out:
# Cloning into 'chemprop'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 7141 (delta 13), reused 23 (delta 10), pack-reused 7111
# Receiving objects: 100% (7141/7141), 286.16 MiB | 21.47 MiB/s, done.
# Resolving deltas: 100% (4984/4984), done.
# Checking out files: 100% (298/298), done.

# %%
# !conda install -q -y -c conda-forge flask>=1.1.2

# %%
# !conda install -q -y -c conda-forge gunicorn>=20.0.4

# %%
# !conda install hyperopt>=0.2.3
# Out:
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - hyperopt
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
# !conda install numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          46 KB
#     certifi-2020.4.5.1         |           py37_0         155 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     numpy-1.18.1               |   py37h94c655d_0           5 KB
#     numpy-base-1.18.1          |   py37h2f8d375_1         4.2 MB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     ------------------------------------------------------------
#                                            Total:         9.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-openblas
#   numpy-base         pkgs/main/linux-64::numpy-base-1.18.1-py37h2f8d375_1
# ...

# %%
# !conda install scikit-learn
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-0.14.1              |             py_0         201 KB
#     scikit-learn-0.22.1        |   py37h22eb022_0         5.3 MB
#     scipy-1.4.1                |   py37habc2bb6_0        14.6 MB
#     ------------------------------------------------------------
#                                            Total:        20.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             pkgs/main/noarch::joblib-0.14.1-py_0
#   scikit-learn       pkgs/main/linux-64::scikit-learn-0.22.1-py37h22eb022_0
#   scipy              pkgs/main/linux-64::scipy-1.4.1-py37habc2bb6_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# scipy-1.4.1          | 14.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
# ...

# %%
# !conda install scipy
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
# !conda install pytorch torchvision cudatoolkit=10.2 -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-10.2.89        |       hfd86e86_1       365.1 MB
#     intel-openmp-2020.1        |              217         780 KB
#     mkl-2020.1                 |              217       129.0 MB
#     ninja-1.9.0                |   py37hfd86e86_0         1.2 MB
#     pytorch-1.0.0              |py3.7_cuda9.0.176_cudnn7.4.1_1       498.7 MB  pytorch
#     torchvision-0.2.2          |             py_3          44 KB  pytorch
#     ------------------------------------------------------------
#                                            Total:       994.7 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !pip install typed-argument-parser>=1.4.3
# !pip install git+https://github.com/bp-kelley/descriptastorus
# Out:
# ...
#   Cloning https://github.com/bp-kelley/descriptastorus to /tmp/pip-req-build-c8ydpnmr
#   Running command git clone -q https://github.com/bp-kelley/descriptastorus /tmp/pip-req-build-c8ydpnmr
# ...
#   Created wheel for descriptastorus: filename=descriptastorus-2.2.0.2-py3-none-any.whl size=59506 sha256=ebdecbf4f058a450ed066b4274b6cf40f7210a499080e91a62305f5b040fbe17
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pgzrjyb0/wheels/f9/c3/4f/e7d01f4f2f1a89aef8f0ef088beb4a94976324f3ee21410b10
# Successfully built descriptastorus
# ...

# %%
# !conda install tqdm
# !conda install matplotlib
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.46.0                |             py_0          60 KB
#     ------------------------------------------------------------
#                                            Total:          60 KB
#
# The following packages will be UPDATED:
#
#   tqdm                                          4.42.1-py_0 --> 4.46.0-py_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# tqdm-4.46.0          | 60 KB     | : 100% 1.0/1 [00:00<00:00, 10.62it/s]
# done
# done
# done
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# /
# ...

# %%
# !conda install -c conda-forge tensorboardx
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tensorboardx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libprotobuf-3.11.4         |       h8b12597_0         4.8 MB  conda-forge
#     protobuf-3.11.4            |   py37h3340039_1         695 KB  conda-forge
#     tensorboardx-2.0           |             py_0          77 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.11.4-h8b12597_0
#   protobuf           conda-forge/linux-64::protobuf-3.11.4-py37h3340039_1
#   tensorboardx       conda-forge/noarch::tensorboardx-2.0-py_0
#
# The following packages will be UPDATED:
#
# ...

# %%
# %cd chemprop
# !pwd
# Out:
# /content/drive/My Drive/Project De Novo/chemprop/chemprop
# /content/drive/My Drive/Project De Novo/chemprop/chemprop

# %%
# !python predict.py --test_path /content/drive/My\ Drive/Project\ De\ Novo/chemprop/GA_top_leads.csv --checkpoint_dir /content/drive/My\ Drive/Project\ De\ Novo/chemprop/SARS-balanced --preds_path /content/drive/My\ Drive/Project\ De\ Novo/chemprop/GA_preds_3clpro.csv --features_generator rdkit_2d_normalized --no_features_scaling
# Out:
# Loading training args
# Loading data
# 65it [00:00, 158321.58it/s]
# 100% 65/65 [00:03<00:00, 19.51it/s]
# Validating SMILES
# Test size = 65
# Predicting with an ensemble of 5 models
#   0% 0/5 [00:00<?, ?it/s]Loading pretrained parameter "encoder.encoder.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.W_i.weight".
# Loading pretrained parameter "encoder.encoder.W_h.weight".
# Loading pretrained parameter "encoder.encoder.W_o.weight".
# Loading pretrained parameter "encoder.encoder.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Moving model to cuda
#
#   0% 0/2 [00:00<?, ?it/s]
# 100% 2/2 [00:00<00:00,  4.18it/s]
#  20% 1/5 [00:04<00:18,  4.61s/it]Loading pretrained parameter "encoder.encoder.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.W_i.weight".
# ...
